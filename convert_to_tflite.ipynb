# %%
from rfdetr import RFDETRSegPreview

# %%
model = RFDETRSegPreview(pretrain_weights="/home/usama-naveed/nail_AR-rfdeter/output/checkpoint_best_total.pth")
model.optimize_for_inference()
# Out:
# Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Using patch size 12 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
# Loading pretrain weights
# ...

# %%
# !pip install rfdetr[onnxexport]
# Out:
# ...
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 1.2 MB/s  0:00:14a 0:00:01m eta 0:00:01
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 1.0 MB/s  0:00:02m 931.3 kB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [onnx_graphsurgeon]32m4/5 [onnx_graphsurgeon]
# ...

# %%
from rfdetr import RFDETRBase

model = RFDETRBase(pretrain_weights= '/home/usama-naveed/nail_AR-rfdeter/output/checkpoint_best_total.pth' )

model.export()
# Out:
# Loading pretrain weights
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 3
#       1 from rfdetr import RFDETRBase
# ----> 3 model = RFDETRBase(pretrain_weights= '/home/usama-naveed/nail_AR-rfdeter/output/checkpoint_best_regular.pth' )
#       5 model.export()
#
# File ~/miniconda3/envs/rf/lib/python3.11/site-packages/rfdetr/detr.py:55, in RFDETR.__init__(self, **kwargs)
#      53 self.model_config = self.get_model_config(**kwargs)
#      54 self.maybe_download_pretrain_weights()
# ---> 55 self.model = self.get_model(self.model_config)
#      56 self.callbacks = defaultdict(list)
#      58 self.model.inference_model = None
#
# File ~/miniconda3/envs/rf/lib/python3.11/site-packages/rfdetr/detr.py:206, in RFDETR.get_model(self, config)
#     202 def get_model(self, config: ModelConfig):
#     203     """
# ...

# %%
from rfdetr import RFDETRBase

model = RFDETRBase(pretrain_weights= '/home/usama-naveed/nail_AR-rfdeter/output/checkpoint_best_total.pth' )

model.export()
# Out:
# Loading pretrain weights
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 3
#       1 from rfdetr import RFDETRBase
# ----> 3 model = RFDETRBase(pretrain_weights= '/home/usama-naveed/nail_AR-rfdeter/output/checkpoint_best_total.pth' )
#       5 model.export()
#
# File ~/miniconda3/envs/rf/lib/python3.11/site-packages/rfdetr/detr.py:55, in RFDETR.__init__(self, **kwargs)
#      53 self.model_config = self.get_model_config(**kwargs)
#      54 self.maybe_download_pretrain_weights()
# ---> 55 self.model = self.get_model(self.model_config)
#      56 self.callbacks = defaultdict(list)
#      58 self.model.inference_model = None
#
# File ~/miniconda3/envs/rf/lib/python3.11/site-packages/rfdetr/detr.py:206, in RFDETR.get_model(self, config)
#     202 def get_model(self, config: ModelConfig):
#     203     """
# ...
